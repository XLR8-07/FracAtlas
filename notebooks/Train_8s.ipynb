# %% [markdown]
# # Training YOLO-8s on the FracAtlas Dataset
# This notebook shows the training of YOLO8s and YOLO8s-seg models on the FracAtlas dataset.

# %% [markdown]
# ## System setup

# %%
#System Information
# !nvidia-smi
# !python --version
# Out:
# Fri Mar  3 20:27:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.49       Driver Version: 528.49       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   55C    P0    29W / 118W |      0MiB /  8192MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#Run If you don't have ultralytics installed
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.49  Python-3.8.12 torch-1.10.2 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# Setup complete  (16 CPUs, 31.4 GB RAM, 203.8/323.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# ## Training of YOLO8s-seg model for segmentation tasks

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=dataset/data.yaml epochs=30 imgsz=600
# Out:
# Ultralytics YOLOv8.0.49  Python-3.8.12 torch-1.10.2 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %% [markdown]
# ## Training results for the segmentation model

# %%
Image(filename="runs/segment/train/results.png", width=600)

# %%
Image(filename="runs/segment/train/confusion_matrix.png", width=600)

# %% [markdown]
# ## Training of YOLO8s model for localization tasks

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=dataset/data.yaml epochs=30 imgsz=600
# Out:
# WARNING  conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.0.49  Python-3.8.12 torch-1.10.2 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %% [markdown]
# ## Training results for the localization model

# %%
Image(filename="runs/detect/train/results.png", width=600)

# %%
Image(filename="runs/detect/train/confusion_matrix.png", width=600)
