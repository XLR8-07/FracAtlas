# %% [markdown]
# # Train YOLOv8s-seg for Instance Segmentation on FractureAtlas Dataset
# This notebook contains training a pretrained YOLOv8s Model on the MLBFR Dataset for Instance Segmentation Task.
#
# **Sourced from [Ultralytics](https://github.com/ultralytics/ultralytics)

# %% [markdown]
# ## Environment Setup

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
# !nvidia-smi
# Out:
# Mon Feb 27 02:37:25 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.24       Driver Version: 528.24       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:06:00.0  On |                  N/A |
# |  0%   50C    P3    41W / 290W |   3154MiB /  8192MiB |     17%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28  Python-3.9.13 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
# Setup complete  (16 CPUs, 31.9 GB RAM, 119.7/931.5 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# ## Training

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=dataset/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.0.28  Python-3.9.13 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
# ...

# %% [markdown]
# ## Training Results

# %%
#Common Results from YOLOv8 
Image(filename="runs/segment/train2/results.png", width=600)

# %%
#Confusion Matrix
Image(filename="runs/segment/train2/confusion_matrix.png", width=600)
