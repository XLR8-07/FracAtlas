# %% [markdown]
# # Train YOLOv8s for Fracture Detection on FractureAtlas Dataset
# This notebook contains training a pretrained YOLOv8s Model on the MLBFR Dataset for Object Detection Task.
#
# **Sourced from [Ultralytics](https://github.com/ultralytics/ultralytics)

# %% [markdown]
# ## Environment Setup

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
# !nvidia-smi
# Out:
# Mon Feb 27 03:43:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.24       Driver Version: 528.24       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:06:00.0  On |                  N/A |
# | 31%   43C    P3    26W / 290W |   2002MiB /  8192MiB |     43%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28  Python-3.9.13 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
# Setup complete  (16 CPUs, 31.9 GB RAM, 119.7/931.5 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# ## Training

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=dataset_no_aug/data.yaml epochs=30 imgsz=640
# Out:
# ...
#
#   0%|          | 0.00/21.5M [00:00<?, ?B/s]
#   1%|          | 112k/21.5M [00:00<00:22, 1.00MB/s]
#   3%|▎         | 592k/21.5M [00:00<00:06, 3.17MB/s]
#   8%|▊         | 1.70M/21.5M [00:00<00:02, 6.99MB/s]
#  11%|█         | 2.39M/21.5M [00:00<00:03, 6.67MB/s]
#  14%|█▍        | 3.05M/21.5M [00:00<00:03, 4.96MB/s]
#  17%|█▋        | 3.73M/21.5M [00:00<00:03, 5.27MB/s]
#  21%|██        | 4.51M/21.5M [00:00<00:03, 4.49MB/s]
#  25%|██▌       | 5.48M/21.5M [00:01<00:02, 5.72MB/s]
#  28%|██▊       | 6.11M/21.5M [00:01<00:03, 4.76MB/s]
#  32%|███▏      | 6.80M/21.5M [00:01<00:03, 4.86MB/s]
#  35%|███▌      | 7.57M/21.5M [00:01<00:02, 5.47MB/s]
#  38%|███▊      | 8.16M/21.5M [00:01<00:02, 4.74MB/s]
#  41%|████      | 8.80M/21.5M [00:01<00:02, 5.18MB/s]
#  43%|████▎     | 9.35M/21.5M [00:01<00:02, 4.94MB/s]
#  46%|████▌     | 9.86M/21.5M [00:02<00:02, 4.77MB/s]
#  48%|████▊     | 10.3M/21.5M [00:02<00:02, 4.73MB/s]
#  50%|█████     | 10.8M/21.5M [00:02<00:02, 4.61MB/s]
# ...

# %% [markdown]
# ## Training Results

# %%
#Common Results from YOLOv8 
Image(filename="runs/detect/train/results.png", width=600)

# %%
#Confusion Matrix
Image(filename="runs/detect/train/confusion_matrix.png", width=600)
